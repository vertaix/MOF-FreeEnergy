# %%
from src.llmprop_inference import predict
import numpy as np

import warnings
warnings.filterwarnings("ignore")

import os
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
# one sample inference

mofname = "SR_nkc_v1-4c_Cu_1_Ch_v2-4c_1anC_Ch_v3-3c_B_Ch_2B_fused_Ch"
mofid = "[Cu][Cu].[O-]C(=O)c1ccc2c(c1)ccc(c2)c1cc2-c3ccc4c(c3)ccc(c4)C3(c4ccc5c(c4)ccc(-c4cc(-c6cc7ccc(-c(c1)c2)cc7cc6)cc(c4)c1ccc2c(c1)ccc(c2)C(=O)[O-])c5)c1ccc2c(c1)ccc(-c1cc(-c4ccc5cc(-c6cc(-c7cc8ccc3cc8cc7)cc(c6)c3ccc6c(c3)ccc(c6)C(=O)[O-])ccc5c4)cc(c1)c1ccc3c(c1)ccc(c3)C(=O)[O-])c2 MOFid-v1.TIMEOUT.cat0.NO_REF;SR_nkc_v1-4c_Cu_1_Ch_v2-4c_1anC_Ch_v3-3c_B_Ch_2B_fused_Ch"
prop_name = "FE_atom" # options: "FE_atom" for free energy, "SE_atom" for strain energy

embeddings, predictions, predicting_time = predict(
    input_mofname=mofname,
    input_mofid=mofid,
    property_name=prop_name
    )

print("-"*50)
print("ground truth: 18.717673989223 KJ/mol")
print(f'predicted {prop_name}:', predictions[0], 'KJ/mol')
print("embeddings shape:", np.array(embeddings).shape)
print('inference time (s): ', predicting_time)
# Out:
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# Predicting took 0:00:02 -> 2.1545379161834717 seconds
# --------------------------------------------------
# ground truth: 18.717673989223 KJ/mol
# predicted FE_atom: 18.814590454101562 KJ/mol
# embeddings shape: (1, 512)
# inference time (s):  2.1545379161834717

# %%
# predicting strain energy

mof_name = "SR_cdze_v1-4c_bicyclooctane_Ch_v2-4c_pyrene_NU_Ch_v3-4c_Ni_1_Ch_v4-4c_B_Ch_1-1B_1TrU_1-1TrU_Ch_1-2B_1DoU_4H_Ch"
mofid_v1 = "[Ni][Ni].[O-]C(=O)C#Cc1cc(C#CC(=O)[O-])c2c3c1ccc1c3c(cc2)c(cc1C#CC(=O)[O-])C#CC(=O)[O-].[O-]C(=O)C#Cc1ccc(cc1)C1=CC23[CH][C](C1C(=C2)c1ccc(cc1)C=Cc1ccc(-c2cc(-c4ccc(C=Cc5ccc3cc5)cc4)c3-c4ccc(cc4)C=Cc4ccc(cc4)C4=CC5(c6ccc(C=Cc7ccc(-c2c3)cc7)cc6)[CH][C](C4C(=C5)C#Cc2ccc(cc2)C(=O)[O-])C#Cc2ccc(cc2)C(=O)[O-])cc1)C#Cc1ccc(cc1)C(=O)[O-] MOFid-v1.TIMEOUT.cat0.NO_REF;SR_cdze_v1-4c_bicyclooctane_Ch_v2-4c_pyrene_NU_Ch_v3-4c_Ni_1_Ch_v4-4c_B_Ch_1-1B_1TrU_1-1TrU_Ch_1-2B_1DoU_4H_Ch"
prop_name = "SE_atom" # options: "FE_atom" for free energy, "SE_atom" for strain energy

embeddings, predictions, predicting_time = predict(
    input_mofname=mofname,
    input_mofid=mofid,
    property_name=prop_name
    )

print("-"*50)
print("ground truth: 8.308300764904619 KJ/mol")
print(f'predicted {prop_name}:', predictions[0], 'KJ/mol')
print("embeddings shape:", np.array(embeddings).shape)
print('inference time (s): ', predicting_time)
# Out:
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
# Predicting took 0:00:02 -> 2.2756829261779785 seconds
# --------------------------------------------------
# ground truth: 8.308300764904619 KJ/mol
# predicted SE_atom: 8.51736068725586 KJ/mol
# embeddings shape: (1, 512)
# inference time (s):  2.2756829261779785

# %%
# two samples inference

mofnames=["SR_nkc_v1-4c_Cu_1_Ch_v2-4c_1anC_Ch_v3-3c_B_Ch_2B_fused_Ch"]*2
mofids=["[Cu][Cu].[O-]C(=O)c1ccc2c(c1)ccc(c2)c1cc2-c3ccc4c(c3)ccc(c4)C3(c4ccc5c(c4)ccc(-c4cc(-c6cc7ccc(-c(c1)c2)cc7cc6)cc(c4)c1ccc2c(c1)ccc(c2)C(=O)[O-])c5)c1ccc2c(c1)ccc(-c1cc(-c4ccc5cc(-c6cc(-c7cc8ccc3cc8cc7)cc(c6)c3ccc6c(c3)ccc(c6)C(=O)[O-])ccc5c4)cc(c1)c1ccc3c(c1)ccc(c3)C(=O)[O-])c2 MOFid-v1.TIMEOUT.cat0.NO_REF;SR_nkc_v1-4c_Cu_1_Ch_v2-4c_1anC_Ch_v3-3c_B_Ch_2B_fused_Ch"]*2
prop_name="FE_atom" # options: "FE_atom" for free energy, "SE_atom" for strain energy

embeddings, predictions, predicting_time = predict(
    input_mofname=mofnames,
    input_mofid=mofids,
    property_name=prop_name
    )

print("-"*50)
print(f'predicted {prop_name}:', predictions, 'KJ/mol')
print("embeddings shape:", np.array(embeddings).shape)
print('inference time (s): ', predicting_time)
# Out:
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Predicting took 0:00:03 -> 2.8047783374786377 seconds
# --------------------------------------------------
# predicted FE_atom: [18.814590454101562, 18.814590454101562] KJ/mol
# embeddings shape: (2, 512)
# inference time (s):  2.8047783374786377

# %%
# maximum number of tokens (default = 2000) can be reduced for even faster inference, 
# but with a potential trade-off in accuracy

tokens_limit = [128, 256, 512, 1024, 2000]
mofname = "SR_frl_v1-4c_Cu_1_Ch_v2-4c_bicyclooctane_Ch_2B_4F_Ch"
mofid = "[Cu][Cu].[O-]C(=O)c1c(F)c(F)c(c(c1F)F)c1c(F)c(F)c(c(c1F)F)C12C=C3C4C(=C1)c1c(F)c(F)c(-c5c(F)c(F)c(c(c5F)F)C5=CC6(C=C7C5C(=C6)c5c(F)c(F)c(-c6c(F)c(F)c(c(c6F)F)C6=CC8(C=C9c%10c(c(c(-c%11c(c(c(C%12=CC%13(C=C(c%14c(c(c(-c%15c(c(c3c(F)c%15F)F)F)c(F)c%14F)F)F)C%12C(=C%13)c3c(F)c(F)c(-c%12c(F)c(F)c(c(c%12F)F)C%12=CC%13(C=C%14c%15c(c(c(-c%16c(c(c(C%17=CC%18(C=C(c%19c(c(c(-c%20c(c(c(C4=C2)c(F)c%20F)F)F)c(F)c%19F)F)F)C%17C(=C%18)c2c(F)c(F)c(-c4c(F)c(F)c(c(c4F)F)C4=CC%17(C=C(c%18c(c(c(-c%19c(c(c7c(F)c%19F)F)F)c(F)c%18F)F)F)C4C(=C%17)c4c(F)c(F)c(-c7c(F)c(F)c(c(c7F)F)C7=CC%17(C=C(c
prop_name = "FE_atom"
ground_truth = 17.9969737547056

print("*"*100)
for max_tokens in tokens_limit:
    embeddings, predictions, predicting_time = predict(
        input_mofname=mofname,
        input_mofid=mofid,
        property_name=prop_name,
        max_length=max_tokens
        )
    
    print("-"*100)
    print(f"{max_tokens} tokens limit") 
    print(f"ground truth: {ground_truth} KJ/mol")
    print(f'predicted {prop_name} :', predictions[0], 'KJ/mol')
    print("MAE:", np.abs(ground_truth - predictions[0]), 'KJ/mol')
    print('inference time (s): ', predicting_time)
    print("*"*100)
# Out:
# ****************************************************************************************************
# Token indices sequence length is longer than the specified maximum sequence length for this model (2218 > 512). Running this sequence through the model will result in indexing errors
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00, 41.20it/s]
# Predicting took 0:00:01 -> 0.9589507579803467 seconds
# ----------------------------------------------------------------------------------------------------
# 128 tokens limit
# ground truth: 17.9969737547056 KJ/mol
# predicted FE_atom : 17.66484260559082 KJ/mol
# MAE: 0.3321311491147796 KJ/mol
# inference time (s):  0.9589507579803467
# ****************************************************************************************************
# Token indices sequence length is longer than the specified maximum sequence length for this model (2218 > 512). Running this sequence through the model will result in indexing errors
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00, 27.51it/s]
# Predicting took 0:00:01 -> 0.7354247570037842 seconds
# ----------------------------------------------------------------------------------------------------
# 256 tokens limit
# ground truth: 17.9969737547056 KJ/mol
# predicted FE_atom : 19.364017486572266 KJ/mol
# MAE: 1.3670437318666657 KJ/mol
# inference time (s):  0.7354247570037842
# ****************************************************************************************************
# Token indices sequence length is longer than the specified maximum sequence length for this model (2218 > 512). Running this sequence through the model will result in indexing errors
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00, 17.91it/s]
# Predicting took 0:00:01 -> 0.8591265678405762 seconds
# ----------------------------------------------------------------------------------------------------
# 512 tokens limit
# ground truth: 17.9969737547056 KJ/mol
# predicted FE_atom : 19.094234466552734 KJ/mol
# MAE: 1.0972607118471345 KJ/mol
# inference time (s):  0.8591265678405762
# ****************************************************************************************************
# Token indices sequence length is longer than the specified maximum sequence length for this model (2218 > 512). Running this sequence through the model will result in indexing errors
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00,  5.82it/s]
# Predicting took 0:00:01 -> 1.097184419631958 seconds
# ----------------------------------------------------------------------------------------------------
# 1024 tokens limit
# ground truth: 17.9969737547056 KJ/mol
# predicted FE_atom : 18.155149459838867 KJ/mol
# MAE: 0.15817570513326729 KJ/mol
# inference time (s):  1.097184419631958
# ****************************************************************************************************
# Token indices sequence length is longer than the specified maximum sequence length for this model (2218 > 512). Running this sequence through the model will result in indexing errors
# Model creation took 0:00:01
# Prediction progress: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
# Predicting took 0:00:02 -> 2.3777265548706055 seconds
# ----------------------------------------------------------------------------------------------------
# 2000 tokens limit
# ground truth: 17.9969737547056 KJ/mol
# predicted FE_atom : 18.026710510253906 KJ/mol
# MAE: 0.02973675554830635 KJ/mol
# inference time (s):  2.3777265548706055
# ****************************************************************************************************
